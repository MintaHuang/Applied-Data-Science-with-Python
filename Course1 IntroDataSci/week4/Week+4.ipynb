# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-data-analysis/resources/0dhYG) course resource._
#
# ---

# %% [markdown]
# # Distributions in Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 所以就想到了：multinomial distribution 是描述k1...k6的 如果6是所有出现所有情况的次数 (掷骰子）k1是掷出1的次数 k1+k2+k3+k4+k5+k6=n   pdf是多维的
# ### Outcome 1 has a probability of 1/2, outcome 2 has a probability of 1/3, and outcome 3 has a probability of 1/6. The number of trials in each experiment n is 5, and the number of repetitions of the experiment reps is 8.
# ### trinomial 的ex  pdf出来的是三维但是x轴们只是两个outcome的次数的frequency 就像binomial pdf出来的是二维的但是x轴只是一个outcome的次数的frequency 没被表现在图上的的另一个outcome可以被推出来

# %%
from IPython.display import Image
Image("MultinomialProbabilityDistributionFunctionsExample_01.png")

# %% [markdown]
# ### 记住binomial distribution是描述k的 是关于次数的 (硬币head的次数） discrete
#
# #### Here we ask for a number from the NumPy binomial distribution.

# %%
Image("屏幕快照 2018-07-27 上午12.52.52.png")

# %%
np.random.binomial(1, 0.5) #input:n & p #output: 一个k，which is the number of “success”.
# Out:
# 1

# %% [markdown]
# #### if we run the simulation a thousand times and divided the result by a thousand. Well you see a number pretty close to 0.5 which means half of the time we had a heads and half of the time we had a tails.

# %%
np.random.binomial(1000, 0.5)/1000
# Out:
# 0.502

# %%
Image("屏幕快照 2018-07-27 上午12.56.22.png")

# %%
np.random.binomial(20,0.5,10000) 
#input： n & p & size  size是重复这个n的次数 #output：size 个 k,which is the number of "success".
# Out:
# array([ 8, 12,  7, ...,  9, 11, 11])

# %%
len(np.random.binomial(20, .5, 10000))
# Out:
# 10000

# %%
chance_of_tornado = 0.01/100
np.random.binomial(100000, chance_of_tornado) #k=12
# Out:
# 12

# %% [markdown]
# #### Let's say the chance of a tornado here in Ann Arbor on any given day, is 1% regardless of the time of year
# #### what's the chance of this happening two days in a row?
# #### My point here though is that modern computational power allows us to very quickly simulate the effects of different parameters in a distribution. Leading to a new way of understanding the problem. You don't have to work out all the math you can quite often simulate the problem instead and observe the results.

# %%
chance_of_tornado = 0.01

tornado_events = np.random.binomial(1, chance_of_tornado, 1000000) #output：一堆 1 or 0
    
two_days_in_a_row = 0
for j in range(1,len(tornado_events)-1):
    if tornado_events[j]==1 and tornado_events[j-1]==1:
        two_days_in_a_row+=1

print('{} tornadoes back to back in {} years'.format(two_days_in_a_row, 1000000/365))
# Out:
# 105 tornadoes back to back in 2739.72602739726 years

# %%
Image("屏幕快照 2018-07-27 上午2.37.34.png")

# %%
np.random.uniform(0, 1)
# Out:
# 0.2705617194125832

# %%
Image("屏幕快照 2018-07-27 上午2.41.46.png")

# %%
np.random.normal(0.75) #mean=0.75
# Out:
# 1.2831885666243905

# %% [markdown]
# Formula for standard deviation
# $$\sqrt{\frac{1}{N} \sum_{i=1}^N (x_i - \overline{x})^2}$$

# %%
distribution = np.random.normal(0.75,size=1000)

np.sqrt(np.sum((np.mean(distribution)-distribution)**2)/len(distribution)) ##sd = around 1
# Out:
# 0.9896845654293578

# %%
np.std(distribution)
# Out:
# 0.9896845654293578

# %%
import scipy.stats as stats

# %% [markdown]
# #### kurtosis measures extreme values in either tail. Distributions with large kurtosis exhibit tail data exceeding the tails of the normal distribution
# #### The standard normal distribution has a kurtosis of 3

# %%
stats.kurtosis(distribution)
# Out:
# 0.3609044569265212

# %%
Image("下载.png")

# %% [markdown]
# #### skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.
# #### The normal distribution is a symmetric distribution with well-behaved tails. This is indicated by the skewness of 0.03≈0

# %%
Image("skewness---mean-median-mode.jpg")

# %%
stats.skew(distribution)
# Out:
# 0.025702948657410834

# %%
Image("屏幕快照 2018-07-27 上午3.10.18.png")

# %%
chi_squared_df2 = np.random.chisquare(2, size=10000)
stats.skew(chi_squared_df2)
# Out:
# 2.0627222640328604

# %%
chi_squared_df5 = np.random.chisquare(5, size=10000)
stats.skew(chi_squared_df5)
# Out:
# 1.1782565212063492

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

output = plt.hist([chi_squared_df2,chi_squared_df5], bins=50, histtype='step', 
                  label=['2 degrees of freedom','5 degrees of freedom'])
plt.legend(loc='upper right')

# %% [markdown]
# # Hypothesis Testing

# %%
df = pd.read_csv('grades.csv')

# %%
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
len(df)
# Out:
# 2315

# %%
early = df[df['assignment1_submission'] <= '2015-12-31']
late = df[df['assignment1_submission'] > '2015-12-31']

# %%
early.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# ...

# %% [markdown]
# #### Note that the date time values are ignored as panda's knows this isn't a number, but an object type.

# %%
early.mean()
# Out:
# assignment1_grade    74.972741
# assignment2_grade    67.252190
# assignment3_grade    61.129050
# assignment4_grade    54.157620
# assignment5_grade    48.634643
# assignment6_grade    43.838980
# dtype: float64

# %%
late.mean()
# Out:
# assignment1_grade    74.017429
# assignment2_grade    66.370822
# assignment3_grade    60.023244
# assignment4_grade    54.058138
# assignment5_grade    48.599402
# assignment6_grade    43.844384
# dtype: float64

# %%
from scipy import stats
stats.ttest_ind?

# %% [markdown]
# #### This is a two-sided test for the null hypothesis that 2 independent samples have identical average (expected) values. This test assumes that the populations have identical variances by default.
# #### 计算test stats时，和confidence level无关，只在最后比较的时候定义 可同时和0.05和0.1比

# %%
stats.ttest_ind(early['assignment1_grade'], late['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.400549944897566, pvalue=0.16148283016060577)

# %%
stats.ttest_ind(early['assignment2_grade'], late['assignment2_grade'])
# Out:
# Ttest_indResult(statistic=1.3239868220912567, pvalue=0.18563824610067967)

# %%
stats.ttest_ind(early['assignment3_grade'], late['assignment3_grade'])
# Out:
# Ttest_indResult(statistic=1.7116160037010733, pvalue=0.08710151634155668)
